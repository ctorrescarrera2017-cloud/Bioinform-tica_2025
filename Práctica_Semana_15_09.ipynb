# %% [markdown]
# <a href="https://colab.research.google.com/github/ctorrescarrera2017-cloud/Bioinform-tica_2025/blob/main/Pr%C3%A1ctica_Semana_15_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Suma
1+3
# Out:
# 4

# %%
# Resta
2-1
# Out:
# 1

# %%
# Multiplicación
2*5
# Out:
# 10

# %%
# División
3/2
# Out:
# 1.5

# %%
# Floor o división de piso (// nos da el resultado truncado sin redondear)
3//2
# Out:
# 1

# %%
# Módulo (nos da el resto)
3%2
# Out:
# 1

# %%
# Potencia (**)
2**2
# Out:
# 4

# %%
# Raíces (como la potencia la revés, si usamos la fracción, entre parénteis)
4**0.5
4**(1/2)
# Out:
# 2.0

# %%
# Orden de operaciones, usando paréntesis
1+10*10+5
# Out:
# 106

# %%
(1+10)*(10+5)
# Out:
# 165

# %%
# Asignamos números a variables
a=5
a*2
# Out:
# 10

# %%
# Reasignamos
a=10
a*10
# Out:
# 100

# %%
mi_valor= 100
mi_ratio= 0.1
mi_precio= mi_valor*mi_ratio

# %%
mi_precio
# Out:
# 10.0

# %%
# Para saber el tipo de la variable uamos type
type(mi_precio)
# Out:
# float

# %%
type(mi_valor)
# Out:
# int
